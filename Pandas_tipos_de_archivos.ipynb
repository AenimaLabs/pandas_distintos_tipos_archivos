# %% [markdown]
# <a href="https://colab.research.google.com/github/AenimaLabs/pandas_distintos_tipos_archivos/blob/main/Pandas_tipos_de_archivos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Trabajando con distintos tipos de archivos

# %% [markdown]
# ##Archivos *CSV*

# %% [markdown]
# ###Documentación oficial
#
# [Leer un csv](https://pandas.pydata.org/docs/reference/api/pandas.read_csv.html)
#
# [Guardar un csv](https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html)

# %% [markdown]
# ### CSV separado por coma

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# Replace 'ruta/al/archivo.csv' with the actual path to your CSV file in Google Drive
csv_path = '/content/drive/MyDrive/OracleOne/superstore_data.csv'

try:

    df_csv_punto_coma = pd.read_csv(csv_path)
    print("CSV file imported successfully:")
    display(df_csv_punto_coma.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {csv_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# CSV file imported successfully:
#       Id  Year_Birth   Education Marital_Status   Income  Kidhome  Teenhome  \
# 0   1826        1970  Graduation       Divorced  84835.0        0         0
# 1      1        1961  Graduation         Single  57091.0        0         0
# 2  10476        1958  Graduation        Married  67267.0        0         1
# 3   1386        1967  Graduation       Together  32474.0        1         1
# 4   5371        1989  Graduation         Single  21474.0        1         0
#
#   Dt_Customer  Recency  MntWines  ...  MntFishProducts  MntSweetProducts  \
# 0   6/16/2014        0       189  ...              111               189
# 1   6/15/2014        0       464  ...                7                 0
# 2   5/13/2014        0       134  ...               15                 2
# 3   11/5/2014        0        10  ...                0                 0
# 4    8/4/2014        0         6  ...               11                 0
#
# ...

# %% [markdown]
# ###CSV separado por punto y coma

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Replace 'ruta/al/archivo.csv' with the actual path to your CSV file in Google Drive
csv_path = '/content/drive/MyDrive/OracleOne/superstore_data_punto_coma.csv'

try:
    # df_csv_punto_coma = pd.read_csv(csv_path, sep=';', nrows=3, usecols=["Id", "Year_Birth", "Income"])
    df_csv_punto_coma = pd.read_csv(csv_path, sep=';', nrows=3, usecols=[0,1,4])
    #nrows es la cantidad de filas que va a leer
    #usecols cuáles columnas voy a traer al df
    #finalmente, las tres primeras filas de las columnas seleccionadas


    print("CSV file imported successfully:")
    display(df_csv_punto_coma.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {csv_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# CSV file imported successfully:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267

# %%
df_csv_punto_coma.to_csv('/content/drive/MyDrive/OracleOne/nuevo_superstore_data_punto_coma.csv', index=False)
#index = False, impide que al guardar genere una nueva columna de índices

# %%
clientes_mercado = pd.read_csv('/content/drive/MyDrive/OracleOne/nuevo_superstore_data_punto_coma.csv')
clientes_mercado
# Out:
#       Id  Year_Birth  Income
# 0   1826        1970   84835
# 1      1        1961   57091
# 2  10476        1958   67267

# %% [markdown]
# ###Formato de codificación

# %%
from google.colab import drive
drive.mount('/content/drive')

import chardet
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
ruta = '/content/drive/MyDrive/OracleOne/datos_sus.csv'

with open(ruta, 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %%
df_formato_codificacion = pd.read_csv(ruta, encoding='ISO-8859-1', sep=';', nrows=5, on_bad_lines='skip')

# %%
display(df_formato_codificacion.head())
# Out:
#   Procedimentos hospitalares do SUS - por local de internação - Brasil
# 0  Valor total por Unidade da Federação e Ano/mês...
# 1                          Período:Jan/2008-Mar/2021
# 2   Fonte: Ministério da Saúde - Sistema de Infor...
# 3                                             Notas:
# 4   Dados referentes aos últimos seis meses, suje...

# %%
df_formato_codificacion
# Out:
#   Procedimentos hospitalares do SUS - por local de internação - Brasil
# 0  Valor total por Unidade da Federação e Ano/mês...
# 1                          Período:Jan/2008-Mar/2021
# 2   Fonte: Ministério da Saúde - Sistema de Infor...
# 3                                             Notas:
# 4   Dados referentes aos últimos seis meses, suje...

# %% [markdown]
# ##Archivos excel

# %% [markdown]
# Documentación oficial:
#
# [Leer excel](https://pandas.pydata.org/docs/reference/api/pandas.read_excel.html)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

xlsx_path = '/content/drive/MyDrive/OracleOne/emisiones_CO2.xlsx'

try:

    df_xlsx = pd.read_excel(xlsx_path)
    print("Archivo importado correctamente:")
    display(df_xlsx.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {csv_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Archivo importado correctamente:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    0.0     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    0.0     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    0.0     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    0.0     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    0.0     NaN     NaN  NaN      NaN
#
#    Quema  Otros  Per Capita
# 0    NaN    NaN         NaN
# 1    NaN    NaN         NaN
# 2    NaN    NaN         NaN
# 3    NaN    NaN         NaN
# 4    NaN    NaN         NaN

# %%
pd.ExcelFile(xlsx_path).sheet_names #nombres de las hojas
# Out:
# ['emisiones_C02', 'emisiones_percapita', 'fuentes']

# %%
#leer una hoja específica
percapita = pd.read_excel(xlsx_path, sheet_name='emisiones_percapita')
display(percapita.head())
# Out:
#          País ISO 3166-1 alpha-3   Año  Total  Carbón  Aceite  Gas  Cemento  \
# 0  Afganistán                AFG  1750    NaN     NaN     NaN  NaN      NaN
# 1  Afganistán                AFG  1751    NaN     NaN     NaN  NaN      NaN
# 2  Afganistán                AFG  1752    NaN     NaN     NaN  NaN      NaN
# 3  Afganistán                AFG  1753    NaN     NaN     NaN  NaN      NaN
# 4  Afganistán                AFG  1754    NaN     NaN     NaN  NaN      NaN
#
#    Quema  Otros
# 0    NaN    NaN
# 1    NaN    NaN
# 2    NaN    NaN
# 3    NaN    NaN
# 4    NaN    NaN

# %%
display(percapita.tail())
# Out:
#          País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 63099  Global                WLD  2017  4749682.0  1908857.0  1610910.0
# 63100  Global                WLD  2018  4792753.0  1919213.0  1596350.0
# 63101  Global                WLD  2019  4775633.0  1896468.0  1589920.0
# 63102  Global                WLD  2020  4497423.0  1807760.0  1427353.0
# 63103  Global                WLD  2021  4693699.0  1893923.0  1496614.0
#
#              Gas   Cemento    Quema    Otros
# 63099   940144.0  198416.0  51579.0  39776.0
# 63100   979965.0  204225.0  53634.0  39366.0
# 63101   984878.0  208309.0  56569.0  39490.0
# 63102   963695.0  208844.0  51981.0  37789.0
# 63103  1001585.0  211472.0  52663.0  37443.0

# %%
display(percapita.sample(5))
# Out:
#                 País ISO 3166-1 alpha-3   Año      Total    Carbón    Aceite  \
# 37506      Marruecos                MAR  1992   973863.0  164707.0  699212.0
# 51190      Eslovenia                SVN  1804        NaN       NaN       NaN
# 17630        Etiopía                ETH  1972    47044.0       0.0   43883.0
# 54379    Suazilandia                SWZ  2001  1051988.0  485533.0  566455.0
# 32027  Liechtenstein                LIE  1953        0.0       NaN       NaN
#
#           Gas   Cemento  Quema  Otros
# 37506  1875.0  108069.0    0.0    NaN
# 51190     NaN       NaN    NaN    NaN
# 17630     0.0    3161.0    0.0    NaN
# 54379     0.0       0.0    0.0    NaN
# 32027     NaN       NaN    NaN    NaN

# %%
fuentes  = pd.read_excel(xlsx_path, sheet_name='fuentes')
display(fuentes.head())
display(fuentes.tail())
# Out:
#          País ISO 3166-1 alpha-3   Año   Total  Carbón  Aceite     Gas  \
# 0  Afganistán                AFG  1750  [NONE]  [NONE]  [NONE]  [NONE]
# 1  Afganistán                AFG  1751  [NONE]  [NONE]  [NONE]  [NONE]
# 2  Afganistán                AFG  1752  [NONE]  [NONE]  [NONE]  [NONE]
# 3  Afganistán                AFG  1753  [NONE]  [NONE]  [NONE]  [NONE]
# 4  Afganistán                AFG  1754  [NONE]  [NONE]  [NONE]  [NONE]
#
#   Cemento   Quema   Otros Per Capita
# 0  [NONE]  [NONE]  [NONE]     [NONE]
# 1  [NONE]  [NONE]  [NONE]     [NONE]
# 2  [NONE]  [NONE]  [NONE]     [NONE]
# 3  [NONE]  [NONE]  [NONE]     [NONE]
# 4  [NONE]  [NONE]  [NONE]     [NONE]
#          País ISO 3166-1 alpha-3   Año                                 Total  \
# 63099  Global                WLD  2017  CDIAC 2022, BP, and Sum of countries
# 63100  Global                WLD  2018  CDIAC 2022, BP, and Sum of countries
# 63101  Global                WLD  2019  CDIAC 2022, BP, and Sum of countries
# ...

# %%
intervalo = pd.read_excel(xlsx_path, sheet_name='emisiones_C02', usecols='A:D', nrows=10)
#usecols permite seleccionar un intervalo de columnas
display(intervalo)
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %%
intervalo.to_excel('/content/drive/MyDrive/OracleOne/nuevo_emisiones_C02.xlsx', index=False)

# %%
pd.read_excel('/content/drive/MyDrive/OracleOne/nuevo_emisiones_C02.xlsx')
# Out:
#          País ISO 3166-1 alpha-3   Año  Total
# 0  Afganistán                AFG  1750      0
# 1  Afganistán                AFG  1751      0
# 2  Afganistán                AFG  1752      0
# 3  Afganistán                AFG  1753      0
# 4  Afganistán                AFG  1754      0
# 5  Afganistán                AFG  1755      0
# 6  Afganistán                AFG  1756      0
# 7  Afganistán                AFG  1757      0
# 8  Afganistán                AFG  1758      0
# 9  Afganistán                AFG  1759      0

# %% [markdown]
# ## Archivos excel desde google sheets

# %%
link = "https://docs.google.com/spreadsheets/d/1npMaqCnYhqDLSx9mTz_-yL0REQifDB2ffZ_ekqnp5f0/edit?gid=1853666196#gid=1853666196"

sheet_id = "1npMaqCnYhqDLSx9mTz_-yL0REQifDB2ffZ_ekqnp5f0"

sheet_name = "emisiones_percapita"

url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet"

# %%
datos_co2_sheet = pd.read_csv(url)
display(datos_co2_sheet.head())
# Out:
#          País ISO 3166-1 alpha-3   Año Total Carbón Aceite  Gas Cemento Quema  \
# 0  Afganistán                AFG  1750     0    NaN    NaN  NaN     NaN   NaN
# 1  Afganistán                AFG  1751     0    NaN    NaN  NaN     NaN   NaN
# 2  Afganistán                AFG  1752     0    NaN    NaN  NaN     NaN   NaN
# 3  Afganistán                AFG  1753     0    NaN    NaN  NaN     NaN   NaN
# 4  Afganistán                AFG  1754     0    NaN    NaN  NaN     NaN   NaN
#
#   Otros Per Capita
# 0   NaN        NaN
# 1   NaN        NaN
# 2   NaN        NaN
# 3   NaN        NaN
# 4   NaN        NaN

# %%
url_percapita = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
pd.read_csv(url_percapita)
# Out:
#              País ISO 3166-1 alpha-3   Año      Total     Carbón     Aceite  \
# 0      Afganistán                AFG  1750        NaN        NaN        NaN
# 1      Afganistán                AFG  1751        NaN        NaN        NaN
# 2      Afganistán                AFG  1752        NaN        NaN        NaN
# 3      Afganistán                AFG  1753        NaN        NaN        NaN
# 4      Afganistán                AFG  1754        NaN        NaN        NaN
# ...           ...                ...   ...        ...        ...        ...
# 63099      Global                WLD  2017  4.749.682  1.908.857  1.610.910
# 63100      Global                WLD  2018  4.792.753  1.919.213  1.596.350
# 63101      Global                WLD  2019  4.775.633  1.896.468  1.589.920
# 63102      Global                WLD  2020  4.497.423  1.807.760  1.427.353
# 63103      Global                WLD  2021  4.693.699  1.893.923  1.496.614
#
#              Gas  Cemento   Quema   Otros
# ...

# %%
sheet_name = "fuentes"
url_fuentes = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet={sheet_name}"
pd.read_csv(url_fuentes)
# Out:
#              País ISO 3166-1 alpha-3   Año  \
# 0      Afganistán                AFG  1750
# 1      Afganistán                AFG  1751
# 2      Afganistán                AFG  1752
# 3      Afganistán                AFG  1753
# 4      Afganistán                AFG  1754
# ...           ...                ...   ...
# 63099      Global                WLD  2017
# 63100      Global                WLD  2018
# 63101      Global                WLD  2019
# 63102      Global                WLD  2020
# 63103      Global                WLD  2021
#
#                                       Total             Carbón  \
# 0                                    [NONE]             [NONE]
# 1                                    [NONE]             [NONE]
# 2                                    [NONE]             [NONE]
# 3                                    [NONE]             [NONE]
# 4                                    [NONE]             [NONE]
# ...

# %% [markdown]
# ## Archivos JSON

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

json_path = '/content/drive/MyDrive/OracleOne/pacientes.json'

try:

    df_jason = pd.read_json(json_path)
    print("Archivo leido correctamente:")
    display(df_jason.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {json_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Archivo leido correctamente:
#    ID_paciente Enfermedad_corazon    IMC Fumador Consumo_alcohol AVC  \
# 0            0                 No  16.60      Sí              No  No
# 1            1                 No  20.34      No              No  Sí
# 2            2                 No  26.58      Sí              No  No
# 3            3                 No  24.21      No              No  No
# 4            4                 No  23.71      No              No  No
#
#    Salud_fisica  Salud_mental Dificultad_caminar Sexo_biologico Rango_edad  \
# 0             3            30                 No       Femenino      55-59
# 1             0             0                 No       Femenino     80 ó +
# 2            20            30                 No      Masculino      65-69
# 3             0             0                 No       Femenino      75-79
# 4            28             0                 Sí       Femenino      40-44
#
# ...

# %%
json_path = '/content/drive/MyDrive/OracleOne/pacientes_2.json'
#contiene información anidada

try:

    df_jason_2 = pd.read_json(json_path)
    print("Archivo leido correctamente:")
    display(df_jason_2.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {json_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# Archivo leido correctamente:
#                                  Investigación   Año  \
# 0  Indicadores clave de enfermedades cardíacas  2020
# 1  Indicadores clave de enfermedades cardíacas  2020
# 2  Indicadores clave de enfermedades cardíacas  2020
#
#                                            Pacientes
# 0  {'ID': '01', 'Rango_edad': '55-59', 'Sexo_biol...
# 1  {'ID': '02', 'Rango_edad': '80 ó +', 'Sexo_bio...
# 2  {'ID': '03', 'Rango_edad': '65-69', 'Sexo_biol...

# %%
#normalize extrae diccionarrios

df_normalizado = pd.json_normalize(df_jason_2['Pacientes'])
display(df_normalizado.head())
# Out:
#    ID Rango_edad Sexo_biologico    Raza    IMC Fumador Consumo_alcohol  \
# 0  01      55-59          Mujer  Blanca  16.60      Sí              No
# 1  02     80 ó +          Mujer  Blanca  20.34      No              No
# 2  03      65-69      Masculino  Blanca  26.58      Sí              No
#
#    Salud_física  Salud_mental Dificultad_caminar Actividad_física  \
# 0             3            30                 No               Sí
# 1             0             0                 No               Sí
# 2            20            30                 No               Sí
#
#   Salud_general  Horas_sueño                Problemas_salud
# 0     Muy buena            5  [Diabetes, Asma, Cancer_piel]
# 1     Muy buena            7                          [AVC]
# 2     Muy buena            8               [Diabetes, Asma]

# %%
#Importando la biblioteca Pandas
import pandas as pd

#Importando el módulo JSON
import json

#Leyendo el archivo json usando el módulo Python JSON
with open(json_path,'r') as f:
    datos_json = json.loads(f.read())

#Normalizando los datos con los parámetros record_path y meta
json_normalizado = pd.json_normalize(datos_json, record_path='Pacientes', meta=['Investigación', 'Año'])

# %%
df_normalizado.to_json('/content/drive/MyDrive/OracleOne/nuevo_pacientes.json')
json_normalizado.to_json('/content/drive/MyDrive/OracleOne/nuevo_pacientes_2.json')

# %% [markdown]
# ### Json desde Api

# %%
import requests
import json

# %%
datos_frutas = requests.get('https://fruityvice.com/api/fruit/all')

# %%
resultado = json.loads(datos_frutas.text)

# %%
pd.DataFrame(resultado)
# Out:
#                   name   id           family             order         genus  \
# 0            Persimmon   52        Ebenaceae           Rosales     Diospyros
# 1           Strawberry    3         Rosaceae           Rosales      Fragaria
# 2               Banana    1         Musaceae      Zingiberales          Musa
# 3               Tomato    5       Solanaceae         Solanales       Solanum
# 4                 Pear    4         Rosaceae           Rosales         Pyrus
# 5               Durian   60        Malvaceae          Malvales         Durio
# 6           Blackberry   64         Rosaceae           Rosales         Rubus
# 7          Lingonberry   65        Ericaceae          Ericales     Vaccinium
# 8                 Kiwi   66    Actinidiaceae  Struthioniformes       Apteryx
# 9               Lychee   67      Sapindaceae        Sapindales        Litchi
# 10           Pineapple   10     Bromeliaceae            Poales        Ananas
# ...

# %%
datos_frutas_normalizados = pd.json_normalize(resultado)

# %%
display(datos_frutas_normalizados.head())
# Out:
#          name  id      family         order      genus  nutritions.calories  \
# 0   Persimmon  52   Ebenaceae       Rosales  Diospyros                   81
# 1  Strawberry   3    Rosaceae       Rosales   Fragaria                   29
# 2      Banana   1    Musaceae  Zingiberales       Musa                   96
# 3      Tomato   5  Solanaceae     Solanales    Solanum                   74
# 4        Pear   4    Rosaceae       Rosales      Pyrus                   57
#
#    nutritions.fat  nutritions.sugar  nutritions.carbohydrates  \
# 0             0.0              18.0                      18.0
# 1             0.4               5.4                       5.5
# 2             0.2              17.2                      22.0
# 3             0.2               2.6                       3.9
# 4             0.1              10.0                      15.0
#
#    nutritions.protein
# 0                 0.0
# 1                 0.8
# 2                 1.0
# 3                 0.9
# ...

# %% [markdown]
# ##Archivos desde html

# %%
datos_html = pd.read_html('/content/drive/MyDrive/OracleOne/peliculas_wikipedia.html')
display(datos_html)
# Out:
# [       0                      1
#  0   1998             100 Movies
#  1   1999              100 Stars
#  2   2000             100 Laughs
#  3   2001            100 Thrills
#  4   2002           100 Passions
#  5   2003  100 Heroes & Villains
#  6   2004              100 Songs
#  7   2005       100 Movie Quotes
#  8   2005              25 Scores
#  9   2006             100 Cheers
#  10  2006            25 Musicals
#  11  2007   100 Movies (Updated)
#  12  2008        AFI's 10 Top 10
#  13   vte                    vte,
#                              Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
# ...

# %%
type(datos_html)
# Out:
# list

# %%
len(datos_html)
# Out:
# 3

# %%
top_peliculas = datos_html[1]
display(top_peliculas.head())
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %%
top_peliculas.to_html('/content/drive/MyDrive/OracleOne/nuevo_top_peliculas.html', index=False)
display(pd.read_html('/content/drive/MyDrive/OracleOne/nuevo_top_peliculas.html'))
# Out:
# [                            Film  Release year              Director  \
#  0                   Citizen Kane          1941          Orson Welles
#  1                     Casablanca          1942        Michael Curtiz
#  2                  The Godfather          1972  Francis Ford Coppola
#  3             Gone with the Wind          1939        Victor Fleming
#  4             Lawrence of Arabia          1962            David Lean
#  ..                           ...           ...                   ...
#  95                 The Searchers          1956             John Ford
#  96              Bringing Up Baby          1938          Howard Hawks
#  97                    Unforgiven          1992        Clint Eastwood
#  98  Guess Who's Coming to Dinner          1967        Stanley Kramer
#  99           Yankee Doodle Dandy          1942        Michael Curtiz
#
#                        Production companies  Rank
#  0                       RKO Radio Pictures     1
# ...

# %%
top_peliculas.to_csv('/content/drive/MyDrive/OracleOne/nuevo_top_peliculas.csv', index=False)
csv_peliculas = pd.read_csv('/content/drive/MyDrive/OracleOne/nuevo_top_peliculas.csv')
display(csv_peliculas.head())
# Out:
#                  Film  Release year              Director  \
# 0        Citizen Kane          1941          Orson Welles
# 1          Casablanca          1942        Michael Curtiz
# 2       The Godfather          1972  Francis Ford Coppola
# 3  Gone with the Wind          1939        Victor Fleming
# 4  Lawrence of Arabia          1962            David Lean
#
#                      Production companies  Rank
# 0                      RKO Radio Pictures     1
# 1                   Warner Bros. Pictures     2
# 2  Paramount Pictures, Alfran Productions     3
# 3         Selznick International Pictures     4
# 4                        Horizon Pictures     5

# %% [markdown]
# ###Archivos desde xml

# %%
datos_xml = pd.read_xml('/content/drive/MyDrive/OracleOne/imdb_top_1000.xml')
display(datos_xml.head())
# Out:
#    index                                        Poster_Link  \
# 0      0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1      1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2      2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3      3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4      4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
#
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  \
# 0                 Drama          9.3
# 1          Crime, Drama          9.2
# 2  Action, Crime, Drama          9.0
# 3          Crime, Drama          9.0
# ...

# %%
datos_xml.to_xml('/content/drive/MyDrive/OracleOne/nuevo_imdb_top_1000.xml', index=False)
pd.read_xml('/content/drive/MyDrive/OracleOne/nuevo_imdb_top_1000.xml')
# Out:
#      index                                        Poster_Link  \
# 0        0  https://m.media-amazon.com/images/M/MV5BMDFkYT...
# 1        1  https://m.media-amazon.com/images/M/MV5BM2MyNj...
# 2        2  https://m.media-amazon.com/images/M/MV5BMTMxNT...
# 3        3  https://m.media-amazon.com/images/M/MV5BMWMwMG...
# 4        4  https://m.media-amazon.com/images/M/MV5BMWU4N2...
# ..     ...                                                ...
# 995    995  https://m.media-amazon.com/images/M/MV5BNGEwMT...
# 996    996  https://m.media-amazon.com/images/M/MV5BODk3Yj...
# 997    997  https://m.media-amazon.com/images/M/MV5BM2U3Yz...
# 998    998  https://m.media-amazon.com/images/M/MV5BZTBmMj...
# 999    999  https://m.media-amazon.com/images/M/MV5BMTY5OD...
#
#                  Series_Title Released_Year Certificate  Runtime  \
# 0    The Shawshank Redemption          1994           A  142 min
# 1               The Godfather          1972           A  175 min
# ...

# %% [markdown]
# ## Archivos sql
#
# [Documentación oficial SQLAlchemy](https://www.sqlalchemy.org/)

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text

# %%
engine = create_engine('sqlite:///:memory:')

# %%
archivo = '/content/drive/MyDrive/OracleOne/clientes_banco.csv'
data_clientes_banco = pd.read_csv(archivo)
display(data_clientes_banco.head())
# Out:
#    ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0     5008804    32    Nivel superior  Relación-estable               2
# 1     5008805    32    Nivel superior  Relación-estable               2
# 2     5008806    58  Nivel intermedio            Casado               2
# 3     5008808    52  Nivel intermedio           Soltero               1
# 4     5008809    52  Nivel intermedio           Soltero               1
#
#   Categoria_de_renta  Ocupacion  Años_empleado  Rendimiento_anual  \
# 0           Empleado       Otro             12           427500.0
# 1           Empleado       Otro             12           427500.0
# 2           Empleado  Seguridad              3           112500.0
# 3   Business Partner     Ventas              8           270000.0
# 4   Business Partner     Ventas              8           270000.0
#
#    Tiene_carro                  Vivienda
# 0            1    Departamento alquilado
# 1            1    Departamento alquilado
# ...

# %%
data_clientes_banco.to_sql('clientes_banco', engine, index=False)
# Out:
# 438463

# %%
inspector = inspect(engine)

# %%
print(inspector.get_table_names())
# Out:
# ['clientes_banco']

# %%
query = text('SELECT * FROM clientes_banco WHERE Categoria_de_renta = "Empleado"')

# %%
empleados_sql = pd.read_sql(sql = str(query), con = engine.connect())
type(empleados_sql)
# Out:
# pandas.core.frame.DataFrame

# %%
empleados_sql
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
empleados_sql.to_sql('empleados_sql', con = engine.connect(), index=False)
# Out:
# 226059

# %%
pd.read_sql_table('empleados_sql', con=engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008815    46    Nivel superior            Casado               2
# 4          5112956    46    Nivel superior            Casado               2
# ...            ...   ...               ...               ...             ...
# 226054     6837905    43  Nivel intermedio            Casado               3
# 226055     6837906    43  Nivel intermedio            Casado               3
# 226056     6839936    34  Nivel intermedio            Casado               3
# 226057     6840222    43  Nivel intermedio           Soltero               1
# 226058     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
pd.read_sql_table('empleados_sql', con=engine.connect(), columns=['ID_Cliente', 'Grado_estudio', 'Rendimiento_anual'])
# Out:
#         ID_Cliente     Grado_estudio  Rendimiento_anual
# 0          5008804    Nivel superior           427500.0
# 1          5008805    Nivel superior           427500.0
# 2          5008806  Nivel intermedio           112500.0
# 3          5008815    Nivel superior           270000.0
# 4          5112956    Nivel superior           270000.0
# ...            ...               ...                ...
# 226054     6837905  Nivel intermedio           355050.0
# 226055     6837906  Nivel intermedio           355050.0
# 226056     6839936  Nivel intermedio           135000.0
# 226057     6840222  Nivel intermedio           103500.0
# 226058     6842885  Nivel intermedio           121500.0
#
# [226059 rows x 3 columns]

# %% [markdown]
# ### Actualizando un banco de datos

# %%
query = "SELECT * FROM clientes_banco"

# %%
pd.read_sql(sql = str(query), con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#Borrar registro
from sqlalchemy.exc import SQLAlchemyError
query = "DELETE FROM clientes_banco WHERE ID_Cliente = 5008804"

try:
  r_set = engine.connect().execute(text(query))

except SQLAlchemyError as e:
    print(e)

else:
    print("Registro borrado correctamente: ", r_set.rowcount)
# Out:
# Registro borrado correctamente:  1

# %%
pd.read_sql_table('clientes_banco', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52  Nivel intermedio           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
#Actualizando datos
from sqlalchemy.exc import SQLAlchemyError
query = "UPDATE clientes_banco SET Grado_estudio= 'Nivel superior' WHERE ID_Cliente = 5008808"

try:
  r_set = engine.connect().execute(text(query))

except SQLAlchemyError as e:
    print(e)

else:
    print("Registro actualizado correctamente: ", r_set.rowcount)
# Out:
# Registro actualizado correctamente:  1

# %%
pd.read_sql_table('clientes_banco', con = engine.connect())
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008805    32    Nivel superior  Relación-estable               2
# 1          5008806    58  Nivel intermedio            Casado               2
# 2          5008808    52    Nivel superior           Soltero               1
# 3          5008809    52  Nivel intermedio           Soltero               1
# 4          5008810    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438457     6840104    62  Nivel intermedio        Divorciado               1
# 438458     6840222    43  Nivel intermedio           Soltero               1
# 438459     6841878    22    Nivel superior           Soltero               1
# 438460     6842765    59  Nivel intermedio            Casado               2
# 438461     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
inspector = inspect(engine)
print(inspector.get_table_names())
# Out:
# ['clientes_banco', 'empleados_sql']

# %% [markdown]
# ##Práctica

# %% [markdown]
# ###Leyendo datos con distintos parámetros

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# Replace 'ruta/al/archivo.csv' with the actual path to your CSV file in Google Drive
csv_path = '/content/drive/MyDrive/OracleOne/datos_sus.csv'

try:

    df_datos_sus = pd.read_csv(csv_path)
    print("CSV file imported successfully:")
    display(df_csv_punto_coma.head())
except FileNotFoundError:
    print(f"Error: The file was not found at {csv_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# An error occurred: 'utf-8' codec can't decode byte 0xe7 in position 56: invalid continuation byte

# %%
import chardet

with open(csv_path, 'rb') as file:
    print(chardet.detect(file.read()))
# Out:
# {'encoding': 'ISO-8859-1', 'confidence': 0.73, 'language': ''}

# %% [markdown]
# * encoding='ISO-8859-1': tipo de codificación de caracteres del archivo. En este caso, es la codificación ISO-8859-1 la que es común en los archivos en idioma portugués.
#
# * sep=';': separador de los valores del archivo. En este caso, es el punto y coma (;).
#
# * skiprows=3: indica que las primeras tres líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
# * skipfooter=9: Indica que las últimas nueve líneas del archivo deben ignorarse ya que no contienen datos relevantes.
#
# * engine='python': el motor utilizado para leer el archivo es Python. Esto es necesario cuando se utiliza el parámetro skipfooter, ya que el motor predeterminado no admite esta opción.

# %%
try:

    df_datos_sus = pd.read_csv(csv_path, encoding='ISO-8859-1', sep=';', skiprows=3, skipfooter = 9, engine='python')
    print("CSV file imported successfully:")
    display(df_datos_sus)
except FileNotFoundError:
    print(f"Error: The file was not found at {csv_path}")
except Exception as e:
    print(f"An error occurred: {e}")
# Out:
# CSV file imported successfully:
#    Unidade da Federação      2008/Jan      2008/Fev      2008/Mar  \
# 0              Rondônia    1388528,39    2931283,42    1541682,52
# 1                  Acre     902416,00    1497206,26    1794028,48
# 2              Amazonas    4735529,42    7118990,57    8196635,49
# 3               Roraima     657889,53     777939,31     718688,03
# 4                  Pará   18864744,11   19553758,20   21937342,70
# 5                 Amapá    1120973,34    1268740,33     974651,24
# 6             Tocantins    3441592,69    4985688,85    6205612,60
# 7              Maranhão   10723506,39   13559679,41   13985142,36
# 8                 Piauí    7985142,43   10079928,25   10298372,45
# 9                 Ceará   15539821,90   25735101,55   28724625,75
# 10  Rio Grande do Norte    5947814,08    9509755,83   10352238,59
# 11              Paraíba   10723002,45   11386274,47   12053643,87
# 12           Pernambuco   14393949,89   24181400,95   29991302,71
# ...

# %% [markdown]
# ###Abriendo excel desde otro link

# %%
link = "https://docs.google.com/spreadsheets/d/1m-yV_lqLm-paNl08FhTFzHdv1WRMvuZpSvbNWw_FzJo/edit?usp=sharing"
sheet_id = "1m-yV_lqLm-paNl08FhTFzHdv1WRMvuZpSvbNWw_FzJo"
url = f"https://docs.google.com/spreadsheets/d/{sheet_id}/gviz/tq?tqx=out:csv&sheet"

emisiones_co2_mundo = pd.read_csv(url)
display(emisiones_co2_mundo.head())
# Out:
#   Country Name country_code                     Region  \
# 0        Aruba          ABW  Latin America & Caribbean
# 1  Afghanistan          AFG                 South Asia
# 2       Angola          AGO         Sub-Saharan Africa
# 3      Albania          ALB      Europe & Central Asia
# 4      Andorra          AND      Europe & Central Asia
#
#                            Indicator Name           1990         1991  \
# 0  CO2 emissions (metric tons per capita)            NaN          NaN
# 1  CO2 emissions (metric tons per capita)    191.745.115  167.681.579
# 2  CO2 emissions (metric tons per capita)    553.661.955  544.538.649
# 3  CO2 emissions (metric tons per capita)  1.819.541.634  124.281.022
# 4  CO2 emissions (metric tons per capita)  7.521.831.658  723.537.924
#
#           1992           1993           1994           1995  ...  \
# 0          NaN            NaN            NaN            NaN  ...
# 1   95.957.742      8.472.111     75.545.827     68.467.956  ...
# ...

# %%
emisiones_co2_mundo.to_csv('/content/drive/MyDrive/OracleOne/emisiones_co2_mundo.csv', index=False)

# %% [markdown]
# ###Leer una tabla desde una página web

# %%
pd.read_html('https://es.wikipedia.org/wiki/Anexo:Pa%C3%ADses_y_territorios_dependientes_por_poblaci%C3%B3n')[0]
# Out:
#      N.º                   País (o territorio dependiente)  \
# 0      1                                             India
# 1      2                                        China[12]​
# 2      3                                    Estados Unidos
# 3      4                                         Indonesia
# 4      5                                          Pakistán
# ..   ...                                               ...
# 241  242                           Islas Cocos (Australia)
# 242  243  Islas Ultramarinas Menores de los Estados Unidos
# 243  244                               Islas Pitcairn (RU)
# 244  NaN                                             Mundo
# 245   N°                   País (o territorio dependiente)
#
#     Proyección exponencial de la población al 1/7/2025[7]​  \
# 0                                        1 417 492 000
# 1                                        1 407 934 000
# 2                                          342 181 000
# ...

# %% [markdown]
# ###Manipulación de base de datos

# %%
import sqlalchemy
from sqlalchemy import create_engine, MetaData, Table, inspect, text
engine = create_engine('sqlite:///:memory:')

# %%
import pandas as pd
archivo = '/content/drive/MyDrive/OracleOne/clientes_banco2.csv'
datos = pd.read_csv(archivo)
datos.to_sql('clientes', engine, index=False)
# Out:
# 438463

# %%
datos_sql = pd.read_sql_table('clientes', con=engine.connect()) #obtener el df

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'UPDATE clientes SET Rendimiento_anual=300000.0 WHERE ID_Cliente=6840104'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros actualizados: ",r_set.rowcount)
# Out:
# #Registros actualizados:  1

# %%
datos_sql
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'DELETE FROM clientes WHERE ID_Cliente=5008809'
try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros borrados: ",r_set.rowcount)
# Out:
# #Registros borrados:  1

# %%
from sqlalchemy.exc import SQLAlchemyError
query = 'INSERT INTO clientes (ID_Cliente, Edad, Grado_estudio, Estado_civil, ' \
        'Tamaño_familia, Categoria_de_renta, Ocupacion, Años_empleado, ' \
        'Rendimiento_anual, Tiene_carro, Vivienda) ' \
        'VALUES (6850985, 33, "Doctorado", "Soltero", 1, "Empleado", "TI", ' \
        '2, 290000, 0, "Casa/Departamento propio")'

try:
  r_set=engine.connect().execute(text(query))
except SQLAlchemyError as e:
  print(e)
else:
  print("#Registros insertados: ",r_set.rowcount)
# Out:
# #Registros insertados:  1

# %%
datos_sql
# Out:
#         ID_Cliente  Edad     Grado_estudio      Estado_civil  Tamaño_familia  \
# 0          5008804    32    Nivel superior  Relación-estable               2
# 1          5008805    32    Nivel superior  Relación-estable               2
# 2          5008806    58  Nivel intermedio            Casado               2
# 3          5008808    52  Nivel intermedio           Soltero               1
# 4          5008809    52  Nivel intermedio           Soltero               1
# ...            ...   ...               ...               ...             ...
# 438458     6840104    62  Nivel intermedio        Divorciado               1
# 438459     6840222    43  Nivel intermedio           Soltero               1
# 438460     6841878    22    Nivel superior           Soltero               1
# 438461     6842765    59  Nivel intermedio            Casado               2
# 438462     6842885    51  Nivel intermedio            Casado               2
#
# ...
